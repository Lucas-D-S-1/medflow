# %% [markdown]
# # 02 — Camada Gold do MedFlow
#
# Calcula os cinco indicadores aprovados (TMH, IPR, IS, CMI e IPH estimado),
# reconcilia os resultados com a Silver e publica marts independentes do BI.
#
# O IPH é uma estimativa de pressão contra a capacidade mensal declarada no
# CNES. Ele não deve ser apresentado como ocupação hospitalar real.

# %%
from pathlib import Path
import sys

BASE = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(BASE) not in sys.path:
    sys.path.insert(0, str(BASE))

from pipeline.gold import calcular_gold
from pipeline.geografia import gerar_geografia

SOBRESCREVER = False

# %%
marts = calcular_gold(base=BASE, sobrescrever=SOBRESCREVER)
geografia = gerar_geografia(base=BASE)
print("\nGOLD VÁLIDA — cinco indicadores e geografia publicados e reconciliados.")
# Out:
# mart_indicador_hospital_mensal                         18,690 linhas
# mart_indicador_hospital_especialidade_mensal           52,525 linhas
# mart_indicador_hospital_cid_periodo                   447,334 linhas
# mart_indicador_regiao_mensal                            1,798 linhas
# mart_indicador_regiao_periodo                              62 linhas
# GOLD VÁLIDA — cinco indicadores e geografia publicados e reconciliados.
